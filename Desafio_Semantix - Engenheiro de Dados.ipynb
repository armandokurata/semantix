# %%
# criar o contexto Spark 
sc = spark.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Criação dos RDDs abrindo os arquivos texto
jul95_rdd = sc.textFile('/FileStore/tables/access_log_Jul95')
ago95_rdd = sc.textFile('/FileStore/tables/access_log_Aug95')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Junção dos 2 RDDs criados
all_dataset_rdd = jul95_rdd + ago95_rdd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Import dos pacotes necessários
import re
from datetime import datetime
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Contagem de linhas do novo RDD criado
all_dataset_rdd.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: 3461613</div>

# %%
# Pegar 15 linhas do RDD
all_dataset_rdd.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[56]: [&#39;199.72.81.55 - - [01/Jul/1995:00:00:01 -0400] &#34;GET /history/apollo/ HTTP/1.0&#34; 200 6245&#39;,
#  &#39;unicomp6.unicomp.net - - [01/Jul/1995:00:00:06 -0400] &#34;GET /shuttle/countdown/ HTTP/1.0&#34; 200 3985&#39;,
#  &#39;199.120.110.21 - - [01/Jul/1995:00:00:09 -0400] &#34;GET /shuttle/missions/sts-73/mission-sts-73.html HTTP/1.0&#34; 200 4085&#39;,
#  &#39;burger.letters.com - - [01/Jul/1995:00:00:11 -0400] &#34;GET /shuttle/countdown/liftoff.html HTTP/1.0&#34; 304 0&#39;,
#  &#39;199.120.110.21 - - [01/Jul/1995:00:00:11 -0400] &#34;GET /shuttle/missions/sts-73/sts-73-patch-small.gif HTTP/1.0&#34; 200 4179&#39;,
#  &#39;burger.letters.com - - [01/Jul/1995:00:00:12 -0400] &#34;GET /images/NASA-logosmall.gif HTTP/1.0&#34; 304 0&#39;,
#  &#39;burger.letters.com - - [01/Jul/1995:00:00:12 -0400] &#34;GET /shuttle/countdown/video/livevideo.gif HTTP/1.0&#34; 200 0&#39;,
#  &#39;205.212.115.106 - - [01/Jul/1995:00:00:12 -0400] &#34;GET /shuttle/countdown/countdown.html HTTP/1.0&#34; 200 3985&#39;,
#  &#39;d104.aa.net - - [01/Jul/1995:00:00:13 -0400] &#34;GET /shuttle/countdown/ HTTP/1.0&#34; 200 3985&#39;,
#  &#39;129.94.144.152 - - [01/Jul/1995:00:00:13 -0400] &#34;GET / HTTP/1.0&#34; 200 7074&#39;,
#  &#39;unicomp6.unicomp.net - - [01/Jul/1995:00:00:14 -0400] &#34;GET /shuttle/countdown/count.gif HTTP/1.0&#34; 200 40310&#39;,
#  &#39;unicomp6.unicomp.net - - [01/Jul/1995:00:00:14 -0400] &#34;GET /images/NASA-logosmall.gif HTTP/1.0&#34; 200 786&#39;,
#  &#39;unicomp6.unicomp.net - - [01/Jul/1995:00:00:14 -0400] &#34;GET /images/KSC-logosmall.gif HTTP/1.0&#34; 200 1204&#39;,
#  &#39;d104.aa.net - - [01/Jul/1995:00:00:15 -0400] &#34;GET /shuttle/countdown/count.gif HTTP/1.0&#34; 200 40310&#39;,
#  &#39;d104.aa.net - - [01/Jul/1995:00:00:15 -0400] &#34;GET /images/NASA-logosmall.gif HTTP/1.0&#34; 200 786&#39;]</div>

# %%
# Função que valida as informações de cada linha do RDD criado
# https://pt.infobyip.com/regularexpressioncalculator.php

def valida_estrutura(linha_rdd):
  
    #################################################################
    # Valida host validando o grupo 1 da expressão regular
	#################################################################

    host = re.search(r'(.*) - - ', linha_rdd)
    host = host.group(1) if host else ''

	#################################################################
    # Valida se a data está no formato válido
	#################################################################
    
    data = re.search(r'\[([0-9A-Za-z\/]*):.*\]', linha_rdd)
    data = data.group(1) if data else ''

 	#################################################################
    # Valida se o status é inteiro e numérico  
    #################################################################

    status = re.search(r'\" ([0-9]+) ', linha_rdd)
    status = int(status.group(1)) if status else 0
    
	#################################################################
    # Valida se o tamanho transferido  é inteiro e numérico
	#################################################################
    
    bytes_transf = re.search(r' ([0-9]+)$', linha_rdd)
    bytes_transf = int(bytes_transf.group(1)) if bytes_transf else 0

   	#################################################################
    # Retorna  os valores tratados
	#################################################################

    return (host, data, status, bytes_transf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Executar a função lambda do Python, criada para linha do RDD
final_rdd = all_dataset_rdd.map(lambda linha_rdd: valida_estrutura(linha_rdd))

# Carrega rdd  no cache, para melhor performance
final_rdd.cache()

# Consulta 15 registros
final_rdd.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: [(&#39;199.72.81.55&#39;, &#39;01/Jul/1995&#39;, 200, 6245),
#  (&#39;unicomp6.unicomp.net&#39;, &#39;01/Jul/1995&#39;, 200, 3985),
#  (&#39;199.120.110.21&#39;, &#39;01/Jul/1995&#39;, 200, 4085),
#  (&#39;burger.letters.com&#39;, &#39;01/Jul/1995&#39;, 304, 0),
#  (&#39;199.120.110.21&#39;, &#39;01/Jul/1995&#39;, 200, 4179),
#  (&#39;burger.letters.com&#39;, &#39;01/Jul/1995&#39;, 304, 0),
#  (&#39;burger.letters.com&#39;, &#39;01/Jul/1995&#39;, 200, 0),
#  (&#39;205.212.115.106&#39;, &#39;01/Jul/1995&#39;, 200, 3985),
#  (&#39;d104.aa.net&#39;, &#39;01/Jul/1995&#39;, 200, 3985),
#  (&#39;129.94.144.152&#39;, &#39;01/Jul/1995&#39;, 200, 7074),
#  (&#39;unicomp6.unicomp.net&#39;, &#39;01/Jul/1995&#39;, 200, 40310),
#  (&#39;unicomp6.unicomp.net&#39;, &#39;01/Jul/1995&#39;, 200, 786),
#  (&#39;unicomp6.unicomp.net&#39;, &#39;01/Jul/1995&#39;, 200, 1204),
#  (&#39;d104.aa.net&#39;, &#39;01/Jul/1995&#39;, 200, 40310),
#  (&#39;d104.aa.net&#39;, &#39;01/Jul/1995&#39;, 200, 786)]</div>

# %%
# Conta quantidade de linhas do RDD tratado
final_rdd.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[59]: 3461613</div>

# %%
# Configurando a sessao spark
from pyspark.sql import SparkSession
from pyspark import SparkContext

# Criando o dataframe "final_df" à partir do RDD final criado (final_rdd)
# https://stackoverflow.com/questions/29383578/how-to-convert-rdd-object-to-dataframe-in-spark

#final_df = sqlContext.createDataFrame(final_rdd)

final_df = final_rdd.toDF().selectExpr('_1 as host', '_2 as timestamp', '_3 as return_code', '_4 as qtd_bytes')

final_df.createOrReplaceTempView("tab_final_df")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----------+-----------+---------+
#                 host|  timestamp|return_code|qtd_bytes|
# +--------------------+-----------+-----------+---------+
#         199.72.81.55|01/Jul/1995|        200|     6245|
# unicomp6.unicomp.net|01/Jul/1995|        200|     3985|
#       199.120.110.21|01/Jul/1995|        200|     4085|
#   burger.letters.com|01/Jul/1995|        304|        0|
#       199.120.110.21|01/Jul/1995|        200|     4179|
#   burger.letters.com|01/Jul/1995|        304|        0|
#   burger.letters.com|01/Jul/1995|        200|        0|
#      205.212.115.106|01/Jul/1995|        200|     3985|
#          d104.aa.net|01/Jul/1995|        200|     3985|
#       129.94.144.152|01/Jul/1995|        200|     7074|
# unicomp6.unicomp.net|01/Jul/1995|        200|    40310|
# unicomp6.unicomp.net|01/Jul/1995|        200|      786|
# unicomp6.unicomp.net|01/Jul/1995|        200|     1204|
#          d104.aa.net|01/Jul/1995|        200|    40310|
#          d104.aa.net|01/Jul/1995|        200|      786|
#          d104.aa.net|01/Jul/1995|        200|     1204|
#       129.94.144.152|01/Jul/1995|        304|        0|
#       199.120.110.21|01/Jul/1995|        200|     1713|
# ppptky391.asahi-n...|01/Jul/1995|        200|     3977|
#   net-1-141.eden.com|01/Jul/1995|        200|    34029|
# +--------------------+-----------+-----------+---------+
# only showing top 20 rows
#
# </div>

# %%
# %sql 
select count(distinct(host)) as host_unicos 
from   tab_final_df
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host_unicos</th></tr></thead><tbody><tr><td>137979</td></tr></tbody></table></div>

# %%
# %sql 
select count(*) as qtd_erro_404 
from   tab_final_df 
where  return_code = '404'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>qtd_erro_404</th></tr></thead><tbody><tr><td>20901</td></tr></tbody></table></div>

# %%
# %sql 
select host as url, count(*) as qtd 
from   tab_final_df 
where  return_code = '404' 
group  by host 
order by count(*) desc
limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>url</th><th>qtd</th></tr></thead><tbody><tr><td>hoohoo.ncsa.uiuc.edu</td><td>251</td></tr><tr><td>piweba3y.prodigy.com</td><td>157</td></tr><tr><td>jbiagioni.npt.nuwc.navy.mil</td><td>132</td></tr><tr><td>piweba1y.prodigy.com</td><td>114</td></tr><tr><td>www-d4.proxy.aol.com</td><td>91</td></tr></tbody></table></div>

# %%
# %sql
select substr(timestamp,1,2) as dia_req, count(*) as qtd_dia 
from   tab_final_df
where  return_code = '404' 
group  by substr(timestamp,1,2)
order  by dia_req
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dia_req</th><th>qtd_dia</th></tr></thead><tbody><tr><td>01</td><td>559</td></tr><tr><td>02</td><td>291</td></tr><tr><td>03</td><td>778</td></tr><tr><td>04</td><td>705</td></tr><tr><td>05</td><td>733</td></tr><tr><td>06</td><td>1013</td></tr><tr><td>07</td><td>1107</td></tr><tr><td>08</td><td>693</td></tr><tr><td>09</td><td>627</td></tr><tr><td>10</td><td>713</td></tr><tr><td>11</td><td>734</td></tr><tr><td>12</td><td>667</td></tr><tr><td>13</td><td>748</td></tr><tr><td>14</td><td>700</td></tr><tr><td>15</td><td>581</td></tr><tr><td>16</td><td>516</td></tr><tr><td>17</td><td>677</td></tr><tr><td>18</td><td>721</td></tr><tr><td>19</td><td>848</td></tr><tr><td>20</td><td>740</td></tr><tr><td>21</td><td>639</td></tr><tr><td>22</td><td>480</td></tr><tr><td>23</td><td>578</td></tr><tr><td>24</td><td>748</td></tr><tr><td>25</td><td>876</td></tr><tr><td>26</td><td>702</td></tr><tr><td>27</td><td>706</td></tr><tr><td>28</td><td>504</td></tr><tr><td>29</td><td>420</td></tr><tr><td>30</td><td>571</td></tr><tr><td>31</td><td>526</td></tr></tbody></table></div>

# %%
# %sql
select sum(qtd_bytes) as total_bytes_retornado
from   tab_final_df
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_bytes_retornado</th></tr></thead><tbody><tr><td>65524314915</td></tr></tbody></table></div>
